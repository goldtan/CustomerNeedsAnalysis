# %% [markdown]
# # Data preprocessing

# %%
import pandas as pd

# %%
review_all = pd.read_json("AMAZON_FASHION.json", orient = 'columns', lines = True)
review_all
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 0             5      True  10 20, 2014  A1D4G1SNUZWQOT  7106116521
# 1             2      True  09 28, 2014  A3DDWDH9PX2YX2  7106116521
# 2             4     False  08 25, 2014  A2MWC41EW7XL15  7106116521
# 3             2      True  08 24, 2014  A2UH2QQ275NV45  7106116521
# 4             3     False  07 27, 2014   A89F3LQADZBS5  7106116521
# ...         ...       ...          ...             ...         ...
# 883631        5      True  02 21, 2017  A1ZSB2Q144UTEY  B01HJHTH5U
# 883632        5      True  11 25, 2016  A2CCDV0J5VB6F2  B01HJHTH5U
# 883633        3      True  11 10, 2016  A3O90PACS7B61K  B01HJHTH5U
# 883634        3      True  11 10, 2016  A2HO94I89U3LNH  B01HJHF97K
# 883635        5      True   08 9, 2016  A2RSX9E79DUHRX  B01HJG5NMW
#
#                reviewerName  \
# 0                     Tracy
# 1                 Sonja Lau
# 2                  Kathleen
# 3               Jodi Stoner
# ...

# %%
review_all.rename(columns = {'asin' : 'productID', 'overall' : 'rating'}, inplace = True)

# %%
review_all = review_all[review_all['vote'] > 0] #다른 사람에게 공감을 한 개 이상 받은 리뷰만

# %%
review_all.columns
# Out:
# Index(['rating', 'verified', 'reviewTime', 'reviewerID', 'productID',
#        'reviewerName', 'reviewText', 'summary', 'unixReviewTime', 'vote',
#        'style', 'image'],
#       dtype='object')

# %%
review_all = review_all.drop(columns = ['verified', 'reviewTime', 'reviewerID', 'reviewerName', 'unixReviewTime', 'vote', 'image'])
review_all = review_all.reset_index(drop = True)
review_all
# Out:
#        rating   productID                                         reviewText  \
# 0           2  7106116521  I agree with the other review, the opening is ...
# 1           4  B00007GDFV  Received the case in less than a week...was ve...
# 2           5  B00007GDFV  I had been looking for a replacement for a cig...
# 3           1  B00008JOQI  We tried these shirts in the pinpoint fabric, ...
# 4           3  B00008JOQI  The fit was a bit awkward for my athletic body...
# ...       ...         ...                                                ...
# 79895       1  B01HJEOBUO  Cute print, material as expected, seams ok, bu...
# 79896       2  B01HJEOBUO  Really sad that the sizing is so inconsistent....
# 79897       3  B01HJEOC9E  The dress is pretty and fits on top, which gre...
# 79898       4  B01HJHTH5U  This dress is quite sexy with the plunging nec...
# 79899       5  B01HJHTH5U  I'm 5'6 175lbs. I'm on the tall side. I wear a...
#
# ...

# %%
review_all['reviewTotal'] = review_all['reviewText'] + " " + review_all['summary']
data = review_all
data
# Out:
#        rating   productID                                         reviewText  \
# 0           2  7106116521  I agree with the other review, the opening is ...
# 1           4  B00007GDFV  Received the case in less than a week...was ve...
# 2           5  B00007GDFV  I had been looking for a replacement for a cig...
# 3           1  B00008JOQI  We tried these shirts in the pinpoint fabric, ...
# 4           3  B00008JOQI  The fit was a bit awkward for my athletic body...
# ...       ...         ...                                                ...
# 79895       1  B01HJEOBUO  Cute print, material as expected, seams ok, bu...
# 79896       2  B01HJEOBUO  Really sad that the sizing is so inconsistent....
# 79897       3  B01HJEOC9E  The dress is pretty and fits on top, which gre...
# 79898       4  B01HJHTH5U  This dress is quite sexy with the plunging nec...
# 79899       5  B01HJHTH5U  I'm 5'6 175lbs. I'm on the tall side. I wear a...
#
# ...

# %% [markdown]
# # Text preprocessing

# %%
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.tag import pos_tag
import re

# %%
review_total = data['reviewTotal'].map(lambda x: str(x).lower()) #소문자로
review_total
# Out:
# 0        i agree with the other review, the opening is ...
# 1        received the case in less than a week...was ve...
# 2        i had been looking for a replacement for a cig...
# 3        we tried these shirts in the pinpoint fabric, ...
# 4        the fit was a bit awkward for my athletic body...
#                                ...
# 79895    cute print, material as expected, seams ok, bu...
# 79896    really sad that the sizing is so inconsistent....
# 79897    the dress is pretty and fits on top, which gre...
# 79898    this dress is quite sexy with the plunging nec...
# 79899    i'm 5'6 175lbs. i'm on the tall side. i wear a...
# Name: reviewTotal, Length: 79900, dtype: object

# %%
review_total = review_total.map(lambda x: re.sub('[^a-zA-Z]', ' ', x)) #특수문자와 숫자 제거
review_total
# Out:
# 0        i agree with the other review  the opening is ...
# 1        received the case in less than a week   was ve...
# 2        i had been looking for a replacement for a cig...
# 3        we tried these shirts in the pinpoint fabric  ...
# 4        the fit was a bit awkward for my athletic body...
#                                ...
# 79895    cute print  material as expected  seams ok  bu...
# 79896    really sad that the sizing is so inconsistent ...
# 79897    the dress is pretty and fits on top  which gre...
# 79898    this dress is quite sexy with the plunging nec...
# 79899    i m        lbs  i m on the tall side  i wear a...
# Name: reviewTotal, Length: 79900, dtype: object

# %%
review_total = review_total.map(word_tokenize) #토큰화
review_total
# Out:
# 0        [i, agree, with, the, other, review, the, open...
# 1        [received, the, case, in, less, than, a, week,...
# 2        [i, had, been, looking, for, a, replacement, f...
# 3        [we, tried, these, shirts, in, the, pinpoint, ...
# 4        [the, fit, was, a, bit, awkward, for, my, athl...
#                                ...
# 79895    [cute, print, material, as, expected, seams, o...
# 79896    [really, sad, that, the, sizing, is, so, incon...
# 79897    [the, dress, is, pretty, and, fits, on, top, w...
# 79898    [this, dress, is, quite, sexy, with, the, plun...
# 79899    [i, m, lbs, i, m, on, the, tall, side, i, wear...
# Name: reviewTotal, Length: 79900, dtype: object

# %%
review_total = review_total.map(pos_tag)
review_total
# Out:
# 0        [(i, NNS), (agree, VBP), (with, IN), (the, DT)...
# 1        [(received, VBD), (the, DT), (case, NN), (in, ...
# 2        [(i, NN), (had, VBD), (been, VBN), (looking, V...
# 3        [(we, PRP), (tried, VBD), (these, DT), (shirts...
# 4        [(the, DT), (fit, NN), (was, VBD), (a, DT), (b...
#                                ...
# 79895    [(cute, JJ), (print, NN), (material, NN), (as,...
# 79896    [(really, RB), (sad, JJ), (that, IN), (the, DT...
# 79897    [(the, DT), (dress, NN), (is, VBZ), (pretty, J...
# 79898    [(this, DT), (dress, NN), (is, VBZ), (quite, R...
# 79899    [(i, JJ), (m, VBP), (lbs, NN), (i, NN), (m, VB...
# Name: reviewTotal, Length: 79900, dtype: object

# %%
#형용사만 사용했을 때가 가장 좋은 결과
nouns = ['NN', 'NNP', 'NNS', 'NNPS']
verbs = ['VB', 'VBD', 'VBG', 'VBN', 'VBP', 'VBZ']
adverbs = ['RB', 'RBR', 'RBS']
adjective = ['JJ', 'JJR', 'JJS']

# %%
lemmatizer = WordNetLemmatizer() 

#표제어 추출 함수
def lemmatize_word(x):
    a = []
    for tup in x: 
        if tup[1] in adjective :
            a.append(lemmatizer.lemmatize(tup[0], 'a'))
        elif tup[1] in nouns:
            a.append(lemmatizer.lemmatize(tup[0], 'n'))
        else :
            pass 
    return a

# %%
review_total = review_total.map(lemmatize_word) #표제어 추출
review_total
# Out:
# 0        [i, other, review, opening, small, i, hook, ex...
# 1        [case, less, week, satisfied, product, problem...
# 2        [i, replacement, cigarette, case, i, d, year, ...
# 3        [shirt, pinpoint, fabric, bad, wrinkled, shirt...
# 4        [fit, bit, awkward, athletic, body, type, fabr...
#                                ...
# 79895    [cute, print, material, seam, small, i, size, ...
# 79896    [sad, sizing, inconsistent, i, black, pink, on...
# 79897    [dress, pretty, top, i, f, i, large, bottom, p...
# 79898    [dress, sexy, neckline, i, person, picture, fr...
# 79899    [i, lb, i, tall, side, i, large, large, comfor...
# Name: reviewTotal, Length: 79900, dtype: object

# %%
stoplist = set(stopwords.words('english'))

#불용어 제거 함수
def stop_word(x):
    a = []
    for word in x: 
        if word not in stoplist: 
            a.append(word)
    return a

# %%
review_total = review_total.map(stop_word) #불용어 제거
review_total
# Out:
# 0        [review, opening, small, hook, expensive, earr...
# 1        [case, less, week, satisfied, product, problem...
# 2        [replacement, cigarette, case, year, several, ...
# 3        [shirt, pinpoint, fabric, bad, wrinkled, shirt...
# 4        [fit, bit, awkward, athletic, body, type, fabr...
#                                ...
# 79895    [cute, print, material, seam, small, size, bre...
# 79896    [sad, sizing, inconsistent, black, pink, one, ...
# 79897    [dress, pretty, top, f, large, bottom, portion...
# 79898    [dress, sexy, neckline, person, picture, frien...
# 79899    [lb, tall, side, large, large, comfortable, am...
# Name: reviewTotal, Length: 79900, dtype: object

# %%
data['reviewWord'] = review_total
data.to_csv("data_all_pre.csv")
data.to_pickle("data_all_pre.pkl")
data
# Out:
#        rating   productID                                         reviewText  \
# 0           2  7106116521  I agree with the other review, the opening is ...
# 1           4  B00007GDFV  Received the case in less than a week...was ve...
# 2           5  B00007GDFV  I had been looking for a replacement for a cig...
# 3           1  B00008JOQI  We tried these shirts in the pinpoint fabric, ...
# 4           3  B00008JOQI  The fit was a bit awkward for my athletic body...
# ...       ...         ...                                                ...
# 79895       1  B01HJEOBUO  Cute print, material as expected, seams ok, bu...
# 79896       2  B01HJEOBUO  Really sad that the sizing is so inconsistent....
# 79897       3  B01HJEOC9E  The dress is pretty and fits on top, which gre...
# 79898       4  B01HJHTH5U  This dress is quite sexy with the plunging nec...
# 79899       5  B01HJHTH5U  I'm 5'6 175lbs. I'm on the tall side. I wear a...
#
# ...
